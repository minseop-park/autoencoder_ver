# %%
# %matplotlib inline 
# lets see all of the supervisions with original image
import numpy as np 
import matplotlib.pyplot as plt 
from dataset import get_test_data, get_train_pair 
import cv2

x, y = get_train_pair(10)
# x, y = get_test_data(10)



for i in range(10):
#     dst = cv2.filter2D(y[i],-1,kernel)
  
    plt.figure(figsize=(18,18))
    plt.subplot(121)
    plt.imshow(x[i], cmap='gray')
    
    plt.subplot(122)
    plt.imshow(y[i], cmap='gray')
    plt.show()
# Out:
# /home/mike/tf/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
